# %%
def o(p):
    def q():
        return '*'*p
    return q

r=o(1)
s=o(2)
print(r()+s())
# Out:
# ***

# %%
print(chr(ord('p')+2))
# Out:
# r

# %%
x='\\\\'
print(x)
# Out:
# \\

# %%
class A:
    def __init__(self,v):
        self.__a=v+1
a=A(0)
print(a.__a)
# Out:
# 1

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %%
class I:
    def __init__(self):
        self.s='abc'
        self.i=0
    def __iter__(self):
        return self
    def __next__(self):
        if self.i==len(self.s):
            raise StopIterration
        v=self.s[self.i]
        self.i +=1
        return v
for x in I():
    print(x, end='')
# Out:
# abc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a89c03c14b72> in <module>()
#      11         self.i +=1
#      12         return v
# ---> 13 for x in I():
#      14     print(x, end='')
#      15
#
# <ipython-input-12-a89c03c14b72> in __next__(self)
#       7     def __next__(self):
#       8         if self.i==len(self.s):
# ----> 9             raise StopIterration
#      10         v=self.s[self.i]
#      11         self.i +=1
#
# NameError: name 'StopIterration' is not defined

# %%
var=1
assert var !=0
print(var)
# Out:
# 1

# %%
try:
    raise Exception
except BaseException:
    print("a")
except Exception:
    print("b")
except:
    print("c")
# Out:
# a

# %%
class A:
    def __init__(self):
        pass
a=A(1)
print(hasattr(a,'A'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-80ac9252ea1b> in <module>()
#       2     def __init__(self):
#       3         pass
# ----> 4 a=A(1)
#       5 print(hasattr(a,'A'))
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
def I(n):
    s = 1
    for i in range(n):
        s+=1
        yield s
        
for x in I(2):
    print(x,end='')
# Out:
# 23

# %%
x = 1
y = 2 

#x,y,z = x,x,y
z,y,z = x,y,z

print(z,y,z)
# Out:
# 2 2 2

# %%
tup = (1,2,3)
x=tup[1]+tup[0]
print(x)
# Out:
# 3

# %%
lst=[1,2]
for v in range(2):
    lst.append(-1,lst[v])
print(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-927f9f527add> in <module>()
#       1 lst=[1,2]
#       2 for v in range(2):
# ----> 3     lst.append(-1,lst[v])
#       4     print(lst)
#
# TypeError: append() takes exactly one argument (2 given)

# %%
def I(n):
    s = '+'
    for i in range(n):
        s += s
        print(s+"---")
        yield s
        
for x in I(2):
    print(x,end='')
# Out:
# ++---
# ++++++---
# ++++

# %%
class A :
    pass
class B(A)

# %%
try:
    raise Exception (1,2,3)
except Exception as e:
    print(len(e.args))
# Out:
# 3

# %%
class Class:
    def __init__ (self):
        pass

object=Class(1)
