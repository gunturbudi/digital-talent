# %%
a=1
b=0
a=a^b
b=a^b
a=a^b
#print(a)
print(b)
print(a)
# Out:
# 1
# 0

# %%
lst=[i for i in range(0,-1)]
print(lst)
# Out:
# []

# %%
tup = (1,2,4,8)
tup=tup[-2:-1]
tup=tup[-1]
print(tup)
# Out:
# 4

# %%
nums=[1,2,3]
vals=nums
del vals[:]
print(nums)
print(vals)
# Out:
# []
# []

# %%
dct={}
dct['1']=(1,2)
dct['2']=(2,1)

for x in dct.keys():
    print(dct[x][1], end=" ")
# Out:
# 2 1

# %%
dec func(a,b):
    return b **a

print(func(b=2,2))
# Out:
#   File "<ipython-input-18-d01909630a3b>", line 1
#     dec func(a,b):
#            ^
# SyntaxError: invalid syntax

# %%
def fun (inp=2, out=3):
    return inp*out

print(fun(out=2))
# Out:
# 4

# %%
class Kotak():
    def __init__(self, p, l, t):
        self.panjang=p
        self.lebar=l
        self.tinggi=t
        
    def hitungVolume(self):
        return p*l*t
    

a=Kotak(1,3,4)
a.hitungVolume()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e062b3f79e1c> in <module>()
#      10
#      11 a=Kotak(1,3,4)
# ---> 12 a.hitungVolume()
#
# <ipython-input-2-e062b3f79e1c> in hitungVolume(self)
#       6
#       7     def hitungVolume(self):
# ----> 8         return p*l*t
#       9
#      10
#
# NameError: name 'p' is not defined
