# %%
i = 0
while i<10:
    print("Halo")
# Out:
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# Halo
# ...
