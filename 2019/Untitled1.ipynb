# %%
a=1
b=0
c=a&b
d=a|b
e=a^b
print(c+d+e)
# Out:
# 2

# %%
lst=[[0,1,2,3] for i in range(2)]
print(lst[2][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-1a3a20404ff1> in <module>()
#       1 lst=[[0,1,2,3] for i in range(2)]
# ----> 2 print(lst[2][0])
#
# IndexError: list index out of range

# %%
def message():
    print("Please, enter a value: ")

message()
a = int(input())
message()
b = int(input())
message()
c = int(input())
# Out:
# Please, enter a value:
# 9
# Please, enter a value:
# 80
# Please, enter a value:
# 9
